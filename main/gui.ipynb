# %%
import IPython.display as ipd
import sys  

from gui_backend import *
# %matplotlib qt5
from IPython.display import display

# %%
"""Choose which recording to investigate
The filtered data option is very 
superficially impolemented. It just uses the 0-6-recording aggrevated data"""

pick_rec_no()
df = pd.read_csv('../n_vocal.csv', index_col=0)
display(df)
# Out:
# interactive(children=(Dropdown(description='Recording you want to explore', options=(3, 5, 6, 8, 9, 10, 11, 12…
#      male vocal  fem vocal.  both vocal.  of total frames
# 53            6           6            1               65
# 52            3           0            0               31
# 51            6           4            2               30
# 50           38          18            7              219
# 49            8           3            3               62
# 48            0           0            0                2
# 47            1           1            0               11
# 46           63          32           13              366
# 45            0           0            0                2
# 44           51          22            7              252
# 43           33          54            8              372
# 33           11          15            2              251
# 32            3           4            0               20
# 31            1           4            0               43
# 30            1           0            0                5
# 29            2           2            0               20
# 28            0           0            0                6
# 27            0           0            0                0
# 20            4           1            1                6
# 9             4           4            1               45
# 8             1           1            0                3
# 6             0           0            1                3
# 5             4           2            1               12
# 3             0           0            0                1
# 19            2           9            0              105
# 18            3           7            1               51
# 15            7           4            1               37
# 14            4           0            2               10
# 12            9           2            1               61
# 11            1           0            0               15
# 10            0           0            0                6
# sum         266         195           52             2112

# %%
"""Choose the time interval to investigate (rerun when recording has been updated)"""
pick_plot_limits()
# Out:
# interactive(children=(FloatSlider(value=0.0, description='Start in seconds', max=4655.64996875, step=0.01, sty…

# %%
"""Make the Spectrogram"""
plt.ioff()
spectrogram()
# Out:
# interactive(children=(IntSlider(value=-150, continuous_update=False, description='Amplitude range: Min', max=3…

# %%
""" Animate a slider that synch's with the sound initiated below. 
    Run this and the cell after quickly after each other: 
    Shift+double enter. WIll only work for short sequences"""
# adjust the resolution value if the red line and audio are out of sync
# increase if the red line is lacking behind the sound/ too slow
# decrease if the red line is before the sound/ too fast
resolution = 7400 
fig, x_dwnsampled, animation_frame = animate_spectrogram(resolution=resolution)
an = FuncAnimation(fig, func=animation_frame, frames=x_dwnsampled, interval=1, repeat=False)
plt.show()

# %%
"""Play the microphone data"""
import IPython.display as ipd
ipd.Audio(daq['data_sl'], rate=daq['sample_rate'], autoplay=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
"Simply draw the spectrogram"
plt.show()
